# %%
# %load_ext autoreload
# %autoreload 2

import sys

#Load up Kelcey's personal functions
sys.path.insert(0, "/home/kelcey/eelg_properties/python_files")
from func import *

#Imports from code I did not write
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord, search_around_sky
from astropy.time import Time
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import glob
# %matplotlib inline
from astropy.io import fits
from itertools import combinations
import pickle
from astropy.cosmology import WMAP9 as cosmo
import seaborn as sns
from astropy.table import Table


#Setting up matplotlib and format it
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('axes', labelsize=27)
#plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=27)
plt.rc('axes', titleweight='bold')
plt.rc('font', family='sans-serif')
plt.rcParams.update({'font.size': 20})
# Out:
# /home/kelcey/anaconda3/envs/hera/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/kelcey/anaconda3/envs/hera/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Notes 6/9
#
# ## Intro to Nuclear Data
#
# ### Nathan Gibson, XCP5
#
#
# - naval nuclear lab
#
# - ASC program
#
# - nuclear physics: mostly ignoring electrons and thinking about the nucleus. Think strong nuclear, weak nuclear, and Coulomb forces
#
# - z number is the charge number, a is mass number
#
# - strong nuclear force: why atoms don't fall apart. we don't totally understand it!
#
# - weak nuclear force more important for radioactive decay, but here we talk more about reaction physics
#
# - nuclear data: when I throw a neutron at the nucelas, what happens and how likely is that to happen?
#
# - types of interactions: scattering, capture, charged particle emission, multiple emission, fission
#
# ### Fision
#
# - fission: split a larger atom in half by firing a neutron at it
#
# - we can observe: cross sections, neutron multipicity, prompt fission neutron spectrum
#
# - resulting particles weight less, must be release of energy! From binding energy
#
# - nuclear physicists = alchemists, thye make gold! Very expensive and ot practical, but they do it.
#
# ### Fusion
#
# - most output energy is in the form of a neutron, so the problem of extracting energy from a fusion reaction is non-trivial
#
# - fusion reactors genreally destroy reactor materials, so design is difficult
#
# - thermonuclear: temp depentent with charged particles
#
# - magnets often used to confine plasma, ICF just tried to slam it together with inertia.
#
# - cross section: cross sectional area of atom, total cross section measures the probabiltiy of interaction
#
# - unit is [barnes] 10^24 cm^2
#
# - neutron transport equation: nuclear transport equation (a linear boltzman equation)
#
# ### Nuclear Data Pipeline
#
# - theory + experiment > evaluation > processing > validation > application
#
# - experimnet constrains theoretical data
#
# - can use differential experiments
#
# - theory at T2 for actinides + light element studies
#
# - evaluation: combine theory + experiment to get a good idea of the data.
#
# - data archeology: assesing old uncertainties
#
# - CSWEG: cross sectional evaluation working group
#
# - processing: resonance reconstruction, resonance broaden while temp goes up, store in NJOY code for example which came from MINX in XCP5
#
# - validation: looking at be-reflected Pu sphere , people have died doing these experiments, we use robots now instead of guys with screw drivers! Work to get behchmark $k_{eff}$, most criticality experiments happen in Nevada now.
#
# - what drives new work: we have good info now, but the sensitivities to any nuclear critical system are very high. Anything wrong is a big problem, especially when we do not consider uncrtainty.
#
# - now we can measure unstable nuclei cross sections, charged particle transport is importnant, think about materials used in new designs,
