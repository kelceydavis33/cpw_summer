# %%
# %load_ext autoreload
# %autoreload 2

import sys

#Load up Kelcey's personal functions
sys.path.insert(0, "/home/kelcey/eelg_properties/python_files")
from func import *

#Imports from code I did not write
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord, search_around_sky
from astropy.time import Time
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import glob
# %matplotlib inline
from astropy.io import fits
from itertools import combinations
import pickle
from astropy.cosmology import WMAP9 as cosmo
import seaborn as sns
from astropy.table import Table


#Setting up matplotlib and format it
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('axes', labelsize=27)
#plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=27)
plt.rc('axes', titleweight='bold')
plt.rc('font', family='sans-serif')
plt.rcParams.update({'font.size': 20})
# Out:
# /home/kelcey/anaconda3/envs/hera/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/kelcey/anaconda3/envs/hera/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Notes 6/4 CPW Intro
#
# ## Weapon Effects: An Intro to Computational Physics
#
# ### Eric Nelson
#
# ## Blasts
#
#
#
# - weapon effects: nuclear winter, fallout, and electromagnetic pulses
#
# - important for national security and civil defense
#
# - non-proliferation: are other people making or testing nuclear weapons?
#
# - book: One second after, will EMP end civilization? no it will not
#
# - nuclear testing stopped 1992. computational physics is a tool for understanding how these weapons work
#
# - we ensure safety, security, reliability
#
# - AGEX: above ground experiments + HPC is a substitute for nuclear testing
#
# - historical data is very important
#
# - detonations have outputs: thermal x-ray radiation, debris(KE), neutrons, gamma rays
#
# - and effects: shock/blast, thermal radiation (light and heat), residual radiation/flalout, atmospheric opmozatopm, EMPs
#
# - ionized atmosheres will effect communications
#
# - 1962: starfish prime test
#
# - book: Glasstone & Dolan: The Effects of Nudlear Weopans 1977 (download from LANL library)
#
# - nuclear winter: soot from atmosphere from nuclear generated fires, 2014: India/Pakistan exchange would kill 1B globally by nuclear winter(Mills 2014), Here, Reisner 2018, no nuclear winter
#
# - first step: model thermal radiation and hot debris (fireball), use radiation hydrodynamic codes (CASSIO)
#
# - hydrodynamic codes solve euler equations on a grid
#
# - Eularian vs Lagrangian  grids, stationary grids vs grid moving with the material
#
# - radiative transport/diffusion equations
#
# - hydro equations: advance or evolve some state one timestep at a tome, on a spatial grid,
#
# - mass density, mass velocity, specific internal energy, source terms drive the system ( like gravity, heat sources,
#
# - constitutive terms: pressure, specific internal energy (e), ask what is driving the system if confused
#
# - lagrangian calculations have material coordinates, grid follows the materials. (this is ours?)
#
# - methods to advancce state in time
#
# - opacity: radiative transport equations, how easily does radiation propogate through a material?
#
#
# - specific energy: energy per unit mass
#
# - magnetohydrodynamics include conductivity
#
# - most systems assume thermal equilibrium
#
#  - distinct material and radiation temperatures
#
#  - cross sections also very important!
#
# ### After fire initiation, blast environment
#
#  - blast arises from x-ray generation, ground conditions effect blast environment
#
#  - HIGRAD: 3D Euclidean hydrodynamic code
#
#  - IF COMPLICATED: **what is the state involved? what is driving the state? what are the constituative models?**
#
#  - evolving some state: fule availability, oxygen avialability,
#
#  - driving force: heat igniting things
#
#  - soot goes much further than fallout
#
#  - uncertainty quantification: recognize things aren't perfect, ask how good are they
#
#  - we can look to natural fires to inform our models, such as LA fires. How do fires propogate in urban environments?
#
# ### EMPs
#
# - why do we care?
#
# - high altitude EMP could upset equipment
#
# - could cause cascading failures to electrical power, fule, comms...
#
# - EMP depends on geomagnetic field
#
# - bring our civilization to a hault??
#
# - types of EMP: physics depends on burst altitude. High altitude is > 30km
#
# - gamma rays from high altitude bursts give geomagnetic electromagnetic pulse (GEMP)
#
# - constructuve interference builds up EMP measured at the ground
#
# - mobility: how do secondary electrons move?
#
# - no generic models, thye have specialized tasks
#
# - compton electrons governed by Lorentz force + drag force to account for interaction with air
#
# - uncertaainty of EMP dpeends on things like damping, important to report
#
# - physics trichotomy: computational physics, experimental physics, and theoretical physics
