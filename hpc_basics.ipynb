# %%
# %load_ext autoreload
# %autoreload 2

import sys

#Load up Kelcey's personal functions
sys.path.insert(0, "/home/kelcey/eelg_properties/python_files")
from func import *

#Imports from code I did not write
import astropy.units as u
import astropy.constants as c
from astropy.coordinates import SkyCoord, search_around_sky
from astropy.time import Time
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import pandas as pd
import glob
# %matplotlib inline
from astropy.io import fits
from itertools import combinations
import pickle
from astropy.cosmology import WMAP9 as cosmo
import seaborn as sns
from astropy.table import Table


#Setting up matplotlib and format it
plt.rcParams['figure.figsize'] = (10, 10)
plt.rc('axes', labelsize=27)
#plt.rc('axes', labelweight='bold')
plt.rc('axes', titlesize=27)
plt.rc('axes', titleweight='bold')
plt.rc('font', family='sans-serif')
plt.rcParams.update({'font.size': 20})
# Out:
# /home/kelcey/anaconda3/envs/hera/lib/python3.9/site-packages/pandas/core/computation/expressions.py:21: UserWarning: Pandas requires version '2.8.4' or newer of 'numexpr' (version '2.7.3' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED
# /home/kelcey/anaconda3/envs/hera/lib/python3.9/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.2' currently installed).
#   from pandas.core import (

# %% [markdown]
# # Notes 6/5
#
#
# ## LANL HPC how to
#
# - use fog machine
#
# - look through LANL phone book for contacts for HPC groups
#
#
# > ssh -Y fg-rfe
#
# - HPC consultants: consult@lanl.gov or call 505-665-4444 ext 3 (ext 1 for IT)
#
# - LANL HPC doccumentation (hpc.lanl.gov), forms page for requests
#
# - red: secret/restricted
#
# - turquoise: collaborative enclave
#
# - recenante down time on the 10th
#
# - training page at HPC page, you can attend! Data Management training coming up
#
# - recenante in turquoise network in restricted enclave
#
# - our desktops are on yellow network
#
# - green: public facing resources
#
# - Rocinante (HPC Cray) replicates tycho and crossroads on smaller scales with intel saphire rapid nodes
#
# - go through slides (17) for unix file sharing on the HPC
#
# - must use ztoken set up + pin
#
# > ssh moniker@fg-rfe@lanl.gov
#
# - to log out
#
# > exit
#
# > cat config PKCS11Provider /usr
#
# **roci for rocinante**
#
#
# > ssh -Y ro-rfe
#
# - can store up to 50 GB on user directory. To check your usage:
#
# > chkhome
#
# - home directory (in your username) is safe from purging
#
# > ls .snapshot
#
# - scratch space: /lustre/scratch_name/user for temporary files
#
# > chkproj consult
#
# .....
#
# > mkdir .ssh
#
# > cd Downloads
#
# - use bash.rc to add commands (like echo)
#
# > module list (only on ro)
#
# > module avail PrgEnv (see if this module is available)
#
# > module load..... (load the module)
#
# > module avail
#
# > modulse spider.python (list all python versions)
#
#
#
# ## Running jobs
#
# - we use the slurm work manager
#
# > sinfo (list partitions on the cluster and the state the nodes are in)
#
# - nodes are denoted with node IDs
#
# > sinfo - p standard
#
# - see allocations per node
#
# - checking what we can run via account manager
#
# > sacctmgr show user -moniker-
#
# - Show associations:
#
# > sacctmgr show user -moniker- with assoc
#
# - 2 hour limit with debug (ro)
#
# > userinfo cluster
#
# - shows same info but general
#
# - top and high are max priority jobs
#
# - check slide 28 for slurm work manager info. slurm bash aliases and info about them also available this slide.
#
# > sque | wc-l
#
# - gives total number of jobs running
#
# > show job XXX (job number)
#
# - shows running job
#
# > sque -u ksdavis
#
# - look ar your jobs
#
# > sque -u ksdavis -S 01/2025
#
# - shows previous jobs. Note sque only shows previously running or finished
#
# - make a directory
#
# > mkdir trianing
#
# - open it
#
# > cd training
#
# - copy in a file
#
# > cp /usr.../hello.c
#
# - show files
#
# > ls
#
# - open text file to edit
#
# > nano hello.c (I prefer nano)
#
# - compile the file
#
# > cc -o hello.hello.c
#
# - interactive job checkout:
#
# > salloc -N1
#
# - that should get you on a node which will tell you the node color
#
# > srun -n 4 ./hello (will start hello executable)
#
# - submit a batch file:
#
# > sbatch hello_ batch
#
# - don't put module commands in bash.rc, write a bash file with module load in that file insted.
#
# - fetch: graphical prgram through software.lanl.gov lets you connect in graphical way
#
# - check job policies for running things longer than a minute or parallel in nature
